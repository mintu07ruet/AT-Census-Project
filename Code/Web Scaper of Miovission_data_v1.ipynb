# %%
# import required modules
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from operator import itemgetter
from selenium import webdriver
import time
import re
import sys

# %%
#!pip install selenium # if need to install, then please uncomment and run it

# %%
# if need to install comment of
#!pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %%
#browser = webdriver.Firefox()

# %%
#https://stackoverflow.com/questions/60669599/how-to-webscrape-password-protected-website
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
import time
import json

# Create new driver
#browser = webdriver.Firefox()
browser = webdriver.Chrome()
browser.get('https://central.miovision.com/')


# We wait for a few seconds for the login page to load
browser.implicitly_wait(10)

# Find fields for email and password
username = browser.find_element(By.NAME, "email")
password = browser.find_element(By.NAME, "password")
# Find button to login
send = browser.find_element(By.CLASS_NAME, 'auth0-lock-submit')
#send = browser.find_element(By.CLASS_NAME, 'auth0-lock-submit')
#send = browser.find_element(By.CLASS, 'cf4ff3b5d.c5faccce1.cfccd0b2a.c901653c3._button-login-password')

# Send username and password 
username.send_keys("juliagris@berkeley.edu") # Change your username email here
password.send_keys("SafeTR3C") # change your access credential here
# Wait for accept cookies button to appear and click it
# WebDriverWait(browser, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "accept-cookies-button"))).click()
# Click the login button
send.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[6], line 20
#      17 browser.implicitly_wait(10)
#      19 # Find fields for email and password
# ---> 20 username = browser.find_element(By.NAME, "email")
#      21 password = browser.find_element(By.NAME, "password")
#      22 # Find button to login
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# ...

# %%
#the sites htm is not structure in a proper term, the site used email instead of username but libray can not identify the term
# email. the above code will open the chrome, then manually insert your username and password to login, then it should work
#automatically for rest of the job

# %%
url = 'https://central.miovision.com/'
exceptlist=[]
from selenium.common.exceptions import NoSuchElementException

# make a GET request
for page in range(0,14): # Change the last digit based on availability of data page number
    urls = 'https://central.miovision.com/studies?page=' + str(page)

    browser.get(urls)
    time.sleep(150)
    html_page = browser.page_source
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(html_page)
    studyids=soup("tr", class_="marker_hover leaf collapsed")
    #print(studyids)
    type(studyids)
    study_nums = [item["data-marker-value"] for item in studyids]
    #print(study_nums)
    print(study_nums)
    for i in range(0,len(study_nums)):
        url2=url+'studies/' + study_nums[i] + '/report'
        # soup.find_all("a")
        # soup("a")
        #print(url2)
        browser.get(url2)
        time.sleep(150)
        html_page2 = browser.page_source
        soup2 = BeautifulSoup(html_page2)
        #print(soup2.prettify())
        from selenium.webdriver.common.by import By
        try:
            button2 = browser.find_element(By.NAME,'commit')
            #for e in button2:
            #    e.click()
            button2.click()
        except NoSuchElementException:
            exceptlist.append(url2)
# Out:
# ['1099886', '1099889', '1099894', '1077815', '1000035', '1000028', '824940', '820932', '1062769', '1062768', '1038493', '1039959', '1038236', '996001', '995998', '972928', '972919', '972912', '963823', '963820', '963739', '959493', '959491', '959487', '977268', '977815', '977810', '977266', '978461', '981315', '977803', '977264', '919485', '919482', '919481', '907168', '907149', '907141', '907163', '907162', '907132', '885138', '885123', '885132', '885136', '885128', '885119', '869329', '869326', '865931', '865930', '865928', '873782', '891325', '856128', '856178', '854496', '854498', '856132', '856177', '857464', '857465', '856186', '854098', '854097', '856182', '857433', '853705', '854096', '854092', '854091', '856188', '856187', '854094', '845529', '845526', '832795', '832793', '832782', '828123', '828121', '824943', '824935', '824941', '824942', '824933', '822278', '822274', '822271', '822272', '822268', '822277', '820930', '814560', '814555', '806228', '813689', '813684', '81368
# ...

# %%
# import unicodedata
# clean_list1 = [x.encode('utf-8') for x in exceptlist]
# print(clean_list1)

# %%
# import csv
# with open("exception_list_pages_14.csv",'w') as resultFile:
#     wr = csv.writer(resultFile, dialect='excel')
#     wr.writerow(exceptlist)

# %%
# for i in range(0,len(exceptlist)):
        
#         # soup.find_all("a")
#         # soup("a")
#         #print(url2)
#         browser.get(exceptlist[i])
#         time.sleep(1)
#         html_page3 = browser.page_source
#         soup2 = BeautifulSoup(html_page3)
#         #print(soup2.prettify())
#         from selenium.webdriver.common.by import By
#         try:
#             button2 = browser.find_element(By.NAME,'commit')
#             button2.click()
#         except NoSuchElementException:
#             exceptlist.append(url2)

# %% [markdown]
# # end of the code
